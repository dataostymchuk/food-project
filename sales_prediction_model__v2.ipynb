# %%
# !wget https://raw.githubusercontent.com/fmardero/FuturoLavoro/master/sales_data/db2.0.csv
# Out:
# --2019-12-14 14:41:30--  https://raw.githubusercontent.com/fmardero/FuturoLavoro/master/sales_data/db2.0.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64734 (63K) [text/plain]
# Saving to: ‘db2.0.csv.15’
#
# db2.0.csv.15        100%[===================>]  63.22K  --.-KB/s    in 0.01s
#
# 2019-12-14 14:41:30 (4.23 MB/s) - ‘db2.0.csv.15’ saved [64734/64734]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('db2.0.csv')
df.rename(columns={'data': 'date', 'somma_polli': 'sales', 'feste': 'holidays', 'fenomeni': 'weather'}, inplace=True)
df.date = pd.to_datetime(df.date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 9 columns):
# date                   1520 non-null datetime64[ns]
# dayname                1520 non-null object
# sales                  1520 non-null int64
# t_media                1520 non-null int64
# t_min                  1520 non-null int64
# umidità_percentuale    1520 non-null int64
# weather                1520 non-null object
# juventus               1520 non-null object
# holidays               83 non-null object
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 107.0+ KB

# %%
df.head()
# Out:
#         date   dayname  sales  ...  weather  juventus         holidays
# 0 2015-01-01   giovedì      6  ...     sole         0  Primo dell'Anno
# 1 2015-01-02   venerdì      9  ...     sole         0              NaN
# 2 2015-01-03    sabato     14  ...     sole         0              NaN
# 3 2015-01-04  domenica     10  ...     sole         0              NaN
# 4 2015-01-05    lunedì     14  ...     sole         0              NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Cleaning Days

# %%
df.dayname.value_counts()
# Out:
# sabato       255
# venerdì      253
# giovedì      252
# mercoledì    250
# martedì      250
# domenica     249
# lunedì        11
# Name: dayname, dtype: int64

# %% [markdown]
# Delate Mondays

# %%
df.drop(index=df.query("dayname == 'lunedì'").index, inplace=True)

# %%
df.dayname.value_counts()
# Out:
# sabato       255
# venerdì      253
# giovedì      252
# mercoledì    250
# martedì      250
# domenica     249
# Name: dayname, dtype: int64

# %% [markdown]
# ## AutoCorrelogram

# %%
from statsmodels.graphics.tsaplots import plot_acf

fig, ax = plt.subplots(figsize=(12, 6))
plot_acf(df.sales.values, lags=65, ax=ax)
plt.title('Sales Autocorrelation', fontsize=15)
plt.show()

# %% [markdown]
# ## Sales PDF

# %%
sns.distplot(df.sales, rug=False)

# %%
sns.boxplot(df.sales)

# %%
df.query('sales < 10')
# Out:
#           date    dayname  sales  ...          weather  juventus         holidays
# 0   2015-01-01    giovedì      6  ...             sole         0  Primo dell'Anno
# 1   2015-01-02    venerdì      9  ...             sole         0              NaN
# 6   2015-01-07  mercoledì      4  ...             sole   serie A              NaN
# 10  2015-01-11   domenica      6  ...          nebbia          0              NaN
# 13  2015-01-15    giovedì      8  ...  pioggia nebbia          0              NaN
# 19  2015-01-22    giovedì      7  ...         pioggia          0              NaN
# 82  2015-04-05   domenica      5  ...         pioggia    serie A           Pasqua
# 83  2015-04-07    martedì      8  ...             sole         0              NaN
# 439 2016-05-31    martedì      9  ...             sole         0              NaN
# 616 2016-12-22    giovedì      9  ...             sole         0              NaN
# 632 2017-01-10    martedì      9  ...             sole         0              NaN
# 852 2017-09-23     sabato      5  ...             sole         0              NaN
#
# [12 rows x 9 columns]

# %% [markdown]
# ### Fist 100 days after opening

# %%
df.iloc[:21]
# Out:
#          date    dayname  sales  ...          weather  juventus         holidays
# 0  2015-01-01    giovedì      6  ...             sole         0  Primo dell'Anno
# 1  2015-01-02    venerdì      9  ...             sole         0              NaN
# 2  2015-01-03     sabato     14  ...             sole         0              NaN
# 3  2015-01-04   domenica     10  ...             sole         0              NaN
# 5  2015-01-06    martedì     13  ...             sole         0         Epifania
# 6  2015-01-07  mercoledì      4  ...             sole   serie A              NaN
# 7  2015-01-08    giovedì     10  ...             sole         0              NaN
# 8  2015-01-09    venerdì     13  ...          nebbia          0              NaN
# 9  2015-01-10     sabato     14  ...          nebbia          0              NaN
# 10 2015-01-11   domenica      6  ...          nebbia          0              NaN
# 11 2015-01-13    martedì     13  ...             sole         0              NaN
# 12 2015-01-14  mercoledì     13  ...          nebbia          0              NaN
# 13 2015-01-15    giovedì      8  ...  pioggia nebbia          0              NaN
# 14 2015-01-16    venerdì     15  ...         pioggia          0              NaN
# 15 2015-01-17     sabato     20  ...         pioggia          0              NaN
# 16 2015-01-18   domenica     18  ...             sole         0              NaN
# 17 2015-01-20    martedì     16  ...          nebbia          0              NaN
# 18 2015-01-21  mercoledì     12  ...         pioggia          0              NaN
# 19 2015-01-22    giovedì      7  ...         pioggia          0              NaN
# 20 2015-01-23    venerdì     11  ...             sole         0              NaN
# 21 2015-01-24     sabato     28  ...             sole         0              NaN
#
# [21 rows x 9 columns]

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df.iloc[:100], x='date', y='sales')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(x=df.loc[:100, 'date'], y=df.loc[:100, 'sales'])
plt.show()

# %% [markdown]
# * Fist 20 days after opening: OK (not anomalies)
# * Days: 2015-04-05/06 (index=82,83) anomalies doe to Easter?

# %%
df.loc[80:85]
# Out:
#          date    dayname  sales  ...   weather  juventus  holidays
# 80 2015-04-03    venerdì     14  ...      sole         0       NaN
# 81 2015-04-04     sabato     17  ...      sole         0       NaN
# 82 2015-04-05   domenica      5  ...  pioggia    serie A    Pasqua
# 83 2015-04-07    martedì      8  ...      sole         0       NaN
# 84 2015-04-08  mercoledì     15  ...      sole         0       NaN
# 85 2015-04-09    giovedì     12  ...      sole         0       NaN
#
# [6 rows x 9 columns]

# %%
df.query("holidays == 'Pasqua'")
# Out:
#          date   dayname  sales  ...   weather  juventus  holidays
# 82 2015-04-05  domenica      5  ...  pioggia    serie A    Pasqua
#
# [1 rows x 9 columns]

# %% [markdown]
# **Easter is a disaster for sales**

# %%
df.loc[439].name
# Out:
# 439

# %%
for date in df.loc[[439, 616, 632, 852], 'date']:
    print(date)
# Out:
# 2016-05-31 00:00:00
# 2016-12-22 00:00:00
# 2017-01-10 00:00:00
# 2017-09-23 00:00:00

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(data=df.loc[400:860], x='date', y='sales')
for date in df.loc[[439, 616, 632, 852], 'date']:
    plt.vlines(x=date, ymin=0, ymax=60, color='r', lw=1.5, ls='--')
plt.show()

# %% [markdown]
# ### Bollinger Bands

# %%
ma_list = []
std_list = []
window = [1, 5, 6, 7]

for idx in range(len(df)):
    if idx > 6:
        ma_val = np.mean([df.iloc[idx-k].sales for k in window])
        std_val = np.std([df.iloc[idx-k].sales for k in window])
    else:
        ma_val = np.nan
        std_val = np.nan
    ma_list.append(ma_val)
    std_list.append(std_val)

df['ma_4'] = ma_list
df['ma_std'] = std_list

# %%
df['ma-3std'] = df.ma_4 - 2*df.ma_std
df['ma+3std'] = df.ma_4 + 2*df.ma_std

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(data=df.loc[400:860], x='date', y='sales', lw=0.5, ls='--')
sns.lineplot(data=df.loc[400:860], x='date', y='ma_4')
sns.lineplot(data=df.loc[400:860], x='date', y='ma-3std', color='red')
sns.lineplot(data=df.loc[400:860], x='date', y='ma+3std', color='red')
plt.show()

# %%
df.tail()
# Out:
#            date    dayname  sales  ...     ma_std    ma-3std    ma+3std
# 1515 2019-11-13  mercoledì     32  ...   8.077747  20.344506  52.655494
# 1516 2019-11-14    giovedì     35  ...   8.466847  22.316306  56.183694
# 1517 2019-11-15    venerdì     54  ...  11.924240  19.901520  67.598480
# 1518 2019-11-16     sabato     52  ...   3.897114  45.955771  61.544229
# 1519 2019-11-17   domenica     43  ...  12.338963  22.822075  72.177925
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Percentage Variations

# %%
df['sales_change'] = df.sales.pct_change(periods=1)

# %%
sns.distplot(df.sales_change.dropna(), rug=False)

# %%
df.query('sales_change > 1.5')
# Out:
#           date    dayname  sales  ...    ma-3std    ma+3std  sales_change
# 21  2015-01-24     sabato     28  ...   9.217670  22.782330      1.545455
# 385 2016-03-26     sabato     26  ...   5.839951  44.660049      1.600000
# 440 2016-06-01  mercoledì     23  ...   6.390793  31.109207      1.555556
# 581 2016-11-11    venerdì     26  ...  -0.374607  39.374607      1.600000
# 612 2016-12-17     sabato     40  ...  11.795300  35.204700      1.666667
# 672 2017-02-25     sabato     43  ...   8.523567  42.976433      2.583333
# 853 2017-09-24   domenica     30  ...  -0.639767  40.639767      5.000000
#
# [7 rows x 14 columns]

# %%
df.loc[[671, 672, 852, 853]]
# Out:
#           date   dayname  sales  ...    ma-3std    ma+3std  sales_change
# 671 2017-02-24   venerdì     12  ...  14.131620  35.368380     -0.520000
# 672 2017-02-25    sabato     43  ...   8.523567  42.976433      2.583333
# 852 2017-09-23    sabato      5  ...  15.226217  36.273783     -0.705882
# 853 2017-09-24  domenica     30  ...  -0.639767  40.639767      5.000000
#
# [4 rows x 14 columns]

# %% [markdown]
# # Dataset

# %%
dataset = df[['sales', 
              't_media',
              't_min',
              'umidità_percentuale', 
              'juventus',
              'sales_change',
              'weather',
              'holidays']].copy()

# %% [markdown]
# ## Day - Month

# %%
def cyclical_feature_encoding(feature, max_val):
    tmp = 2 * np.pi * feature / float(max_val)
    return pd.Series(np.sin(tmp), name=f'{feature.name}_sin'), pd.Series(np.cos(tmp), name=f'{feature.name}_cos')


dataset['day_sin'], dataset['day_cos'] = cyclical_feature_encoding(df.date.dt.dayofweek, max_val=6)
dataset['month_sin'], dataset['month_cos'] = cyclical_feature_encoding(df.date.dt.month, max_val=12)

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='day_sin', y='day_cos', data=dataset)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='month_sin', y='month_cos', data=dataset)
plt.show()

# %% [markdown]
# ## Teams

# %%
dataset.juventus = dataset.juventus.apply(lambda x: 0 if x == '0' else 1)

# %% [markdown]
# ## Lag

# %%
lag_window = [1, 5, 6, 7, 11, 12, 13]
lag_columns = ['sales', 'weather', 'juventus', 'holidays']

# %%
for lag in lag_window:
    for col in lag_columns:
        dataset[f'lag{lag}_{col}'] = dataset[col].shift(lag)

# %%
dataset = dataset.iloc[max(lag_window):]

# %% [markdown]
# ## Holidays

# %%
dataset.holidays.unique()
# Out:
# array([nan, 'Giovedì Grasso', 'San Valentino', 'Carnevale',
#        'Martedì Grasso', 'Festa di San Giuseppe', 'Domenica delle Palme',
#        'Pasqua', 'Anniversario della Liberazione', 'Festa dei Lavoratori',
#        'Festa della Mamma', 'Pentecoste', 'Festa della Repubblica',
#        'Ferragosto', 'Ognissanti', 'Immacolata Concezione',
#        'Santo Stefano', "Ultimo dell'Anno", 'Epifania',
#        'Giorno dei Morti', "Primo dell'Anno"], dtype=object)

# %%
dataset = pd.concat([dataset, pd.get_dummies(dataset.holidays, dummy_na=False)], axis=1)
dataset.drop(columns=['holidays'], inplace=True)

# %%
for lag in lag_window:
    col = f'lag{lag}_holidays'
    dataset = pd.concat([dataset, pd.get_dummies(dataset[col], dummy_na=False, prefix=f'lag{lag}')], axis=1)
    dataset.drop(columns=[col], inplace=True)

# %%
dataset.columns.tolist()
# Out:
# ['sales',
#  't_media',
#  't_min',
#  'umidità_percentuale',
#  'juventus',
#  'sales_change',
#  'weather',
#  'day_sin',
#  'day_cos',
#  'month_sin',
#  'month_cos',
#  'lag1_sales',
#  'lag1_weather',
#  'lag1_juventus',
#  'lag5_sales',
#  'lag5_weather',
#  'lag5_juventus',
#  'lag6_sales',
#  'lag6_weather',
#  'lag6_juventus',
#  'lag7_sales',
#  'lag7_weather',
#  'lag7_juventus',
#  'lag11_sales',
#  'lag11_weather',
#  'lag11_juventus',
#  'lag12_sales',
#  'lag12_weather',
#  'lag12_juventus',
#  'lag13_sales',
#  'lag13_weather',
#  'lag13_juventus',
#  'Anniversario della Liberazione',
#  'Carnevale',
#  'Domenica delle Palme',
#  'Epifania',
#  'Ferragosto',
#  'Festa dei Lavoratori',
#  'Festa della Mamma',
#  'Festa della Repubblica',
#  'Festa di San Giuseppe',
#  'Giorno dei Morti',
#  'Giovedì Grasso',
#  'Immacolata Concezione',
#  'Martedì Grasso',
#  'Ognissanti',
#  'Pasqua',
#  'Pentecoste',
#  "Primo dell'Anno",
#  'San Valentino',
#  'Santo Stefano',
#  "Ultimo dell'Anno",
#  'lag1_Anniversario della Liberazione',
#  'lag1_Carnevale',
#  'lag1_Domenica delle Palme',
#  'lag1_Epifania',
#  'lag1_Ferragosto',
#  'lag1_Festa dei Lavoratori',
#  'lag1_Festa della Mamma',
#  'lag1_Festa della Repubblica',
#  'lag1_Festa di San Giuseppe',
#  'lag1_Giorno dei Morti',
#  'lag1_Giovedì Grasso',
#  'lag1_Immacolata Concezione',
#  'lag1_Martedì Grasso',
#  'lag1_Ognissanti',
#  'lag1_Pasqua',
#  'lag1_Pentecoste',
#  "lag1_Primo dell'Anno",
#  'lag1_San Valentino',
#  'lag1_Santo Stefano',
#  "lag1_Ultimo dell'Anno",
#  'lag5_Anniversario della Liberazione',
#  'lag5_Carnevale',
#  'lag5_Domenica delle Palme',
#  'lag5_Epifania',
#  'lag5_Ferragosto',
#  'lag5_Festa dei Lavoratori',
#  'lag5_Festa della Mamma',
#  'lag5_Festa della Repubblica',
#  'lag5_Festa di San Giuseppe',
#  'lag5_Giorno dei Morti',
#  'lag5_Giovedì Grasso',
#  'lag5_Immacolata Concezione',
#  'lag5_Martedì Grasso',
#  'lag5_Ognissanti',
#  'lag5_Pasqua',
#  'lag5_Pentecoste',
#  "lag5_Primo dell'Anno",
#  'lag5_San Valentino',
#  'lag5_Santo Stefano',
#  "lag5_Ultimo dell'Anno",
#  'lag6_Anniversario della Liberazione',
#  'lag6_Carnevale',
#  'lag6_Domenica delle Palme',
#  'lag6_Epifania',
#  'lag6_Ferragosto',
#  'lag6_Festa dei Lavoratori',
#  'lag6_Festa della Mamma',
#  'lag6_Festa della Repubblica',
#  'lag6_Festa di San Giuseppe',
#  'lag6_Giorno dei Morti',
#  'lag6_Giovedì Grasso',
#  'lag6_Immacolata Concezione',
#  'lag6_Martedì Grasso',
#  'lag6_Ognissanti',
#  'lag6_Pasqua',
#  'lag6_Pentecoste',
#  "lag6_Primo dell'Anno",
#  'lag6_San Valentino',
#  'lag6_Santo Stefano',
#  "lag6_Ultimo dell'Anno",
#  'lag7_Anniversario della Liberazione',
#  'lag7_Carnevale',
#  'lag7_Domenica delle Palme',
#  'lag7_Epifania',
#  'lag7_Ferragosto',
#  'lag7_Festa dei Lavoratori',
#  'lag7_Festa della Mamma',
#  'lag7_Festa della Repubblica',
#  'lag7_Festa di San Giuseppe',
#  'lag7_Giorno dei Morti',
#  'lag7_Giovedì Grasso',
#  'lag7_Immacolata Concezione',
#  'lag7_Martedì Grasso',
#  'lag7_Ognissanti',
#  'lag7_Pasqua',
#  'lag7_Pentecoste',
#  "lag7_Primo dell'Anno",
#  'lag7_San Valentino',
#  'lag7_Santo Stefano',
#  "lag7_Ultimo dell'Anno",
#  'lag11_Anniversario della Liberazione',
#  'lag11_Carnevale',
#  'lag11_Domenica delle Palme',
#  'lag11_Epifania',
#  'lag11_Ferragosto',
#  'lag11_Festa dei Lavoratori',
#  'lag11_Festa della Mamma',
#  'lag11_Festa della Repubblica',
#  'lag11_Festa di San Giuseppe',
#  'lag11_Giorno dei Morti',
#  'lag11_Giovedì Grasso',
#  'lag11_Immacolata Concezione',
#  'lag11_Martedì Grasso',
#  'lag11_Ognissanti',
#  'lag11_Pasqua',
#  'lag11_Pentecoste',
#  "lag11_Primo dell'Anno",
#  'lag11_San Valentino',
#  'lag11_Santo Stefano',
#  "lag11_Ultimo dell'Anno",
#  'lag12_Anniversario della Liberazione',
#  'lag12_Carnevale',
#  'lag12_Domenica delle Palme',
#  'lag12_Epifania',
#  'lag12_Ferragosto',
#  'lag12_Festa dei Lavoratori',
#  'lag12_Festa della Mamma',
#  'lag12_Festa della Repubblica',
#  'lag12_Festa di San Giuseppe',
#  'lag12_Giorno dei Morti',
#  'lag12_Giovedì Grasso',
#  'lag12_Immacolata Concezione',
#  'lag12_Martedì Grasso',
#  'lag12_Ognissanti',
#  'lag12_Pasqua',
#  'lag12_Pentecoste',
#  "lag12_Primo dell'Anno",
#  'lag12_San Valentino',
#  'lag12_Santo Stefano',
#  "lag12_Ultimo dell'Anno",
#  'lag13_Anniversario della Liberazione',
#  'lag13_Carnevale',
#  'lag13_Domenica delle Palme',
#  'lag13_Epifania',
#  'lag13_Ferragosto',
#  'lag13_Festa dei Lavoratori',
#  'lag13_Festa della Mamma',
#  'lag13_Festa della Repubblica',
#  'lag13_Festa di San Giuseppe',
#  'lag13_Giorno dei Morti',
#  'lag13_Giovedì Grasso',
#  'lag13_Immacolata Concezione',
#  'lag13_Martedì Grasso',
#  'lag13_Ognissanti',
#  'lag13_Pasqua',
#  'lag13_Pentecoste',
#  "lag13_Primo dell'Anno",
#  'lag13_San Valentino',
#  'lag13_Santo Stefano',
#  "lag13_Ultimo dell'Anno"]

# %% [markdown]
# ## Weather

# %%
df.weather.unique()
# Out:
# array(['sole', 'nebbia ', 'pioggia nebbia ', 'pioggia ',
#        'pioggia temporale nebbia ', 'pioggia temporale ', 'temporale ',
#        'pioggia neve nebbia ', 'neve ', 'pioggia neve '], dtype=object)

# %%
dataset = pd.concat([dataset, pd.get_dummies(dataset.weather, drop_first=True, dummy_na=False)], axis=1)
dataset.drop(columns=['weather'], inplace=True)

# %%
for lag in lag_window:
    col = f'lag{lag}_weather'
    dataset = pd.concat([dataset, pd.get_dummies(dataset[col], drop_first=True, dummy_na=False, prefix=f'lag{lag}')], axis=1)
    dataset.drop(columns=[col], inplace=True)

# %% [markdown]
# ## Check Dataset has no empty columns

# %%
with pd.option_context('display.max_rows', -1, 'display.max_columns', 5):
    print(dataset.isnull().any(axis=0))
# Out:
#                                         False
# sales                                   False
# t_media                                 False
# t_min                                   False
# umidità_percentuale                     False
# juventus                                False
# sales_change                            False
# day_sin                                 False
# day_cos                                 False
# month_sin                               False
# month_cos                               False
# lag1_sales                              False
# lag1_juventus                           False
# lag5_sales                              False
# lag5_juventus                           False
# lag6_sales                              False
# lag6_juventus                           False
# lag7_sales                              False
# lag7_juventus                           False
# lag11_sales                             False
# lag11_juventus                          False
# lag12_sales                             False
# lag12_juventus                          False
# lag13_sales                             False
# lag13_juventus                          False
# Anniversario della Liberazione          False
# Carnevale                               False
# Domenica delle Palme                    False
# Epifania                                False
# Ferragosto                              False
# Festa dei Lavoratori                    False
# Festa della Mamma                       False
# Festa della Repubblica                  False
# Festa di San Giuseppe                   False
# Giorno dei Morti                        False
# Giovedì Grasso                          False
# Immacolata Concezione                   False
# Martedì Grasso                          False
# Ognissanti                              False
# Pasqua                                  False
# Pentecoste                              False
# Primo dell'Anno                         False
# San Valentino                           False
# Santo Stefano                           False
# Ultimo dell'Anno                        False
# lag1_Anniversario della Liberazione     False
# lag1_Carnevale                          False
# lag1_Domenica delle Palme               False
# lag1_Epifania                           False
# lag1_Ferragosto                         False
# lag1_Festa dei Lavoratori               False
# lag1_Festa della Mamma                  False
# lag1_Festa della Repubblica             False
# lag1_Festa di San Giuseppe              False
# lag1_Giorno dei Morti                   False
# lag1_Giovedì Grasso                     False
# lag1_Immacolata Concezione              False
# lag1_Martedì Grasso                     False
# lag1_Ognissanti                         False
# lag1_Pasqua                             False
# lag1_Pentecoste                         False
# lag1_Primo dell'Anno                    False
# lag1_San Valentino                      False
# lag1_Santo Stefano                      False
# lag1_Ultimo dell'Anno                   False
# lag5_Anniversario della Liberazione     False
# lag5_Carnevale                          False
# lag5_Domenica delle Palme               False
# lag5_Epifania                           False
# lag5_Ferragosto                         False
# lag5_Festa dei Lavoratori               False
# lag5_Festa della Mamma                  False
# lag5_Festa della Repubblica             False
# lag5_Festa di San Giuseppe              False
# lag5_Giorno dei Morti                   False
# lag5_Giovedì Grasso                     False
# lag5_Immacolata Concezione              False
# lag5_Martedì Grasso                     False
# lag5_Ognissanti                         False
# lag5_Pasqua                             False
# lag5_Pentecoste                         False
# lag5_Primo dell'Anno                    False
# lag5_San Valentino                      False
# lag5_Santo Stefano                      False
# lag5_Ultimo dell'Anno                   False
# lag6_Anniversario della Liberazione     False
# lag6_Carnevale                          False
# lag6_Domenica delle Palme               False
# lag6_Epifania                           False
# lag6_Ferragosto                         False
# lag6_Festa dei Lavoratori               False
# lag6_Festa della Mamma                  False
# lag6_Festa della Repubblica             False
# lag6_Festa di San Giuseppe              False
# lag6_Giorno dei Morti                   False
# lag6_Giovedì Grasso                     False
# lag6_Immacolata Concezione              False
# lag6_Martedì Grasso                     False
# lag6_Ognissanti                         False
# lag6_Pasqua                             False
# lag6_Pentecoste                         False
# lag6_Primo dell'Anno                    False
# lag6_San Valentino                      False
# lag6_Santo Stefano                      False
# lag6_Ultimo dell'Anno                   False
# lag7_Anniversario della Liberazione     False
# lag7_Carnevale                          False
# lag7_Domenica delle Palme               False
# lag7_Epifania                           False
# lag7_Ferragosto                         False
# lag7_Festa dei Lavoratori               False
# lag7_Festa della Mamma                  False
# lag7_Festa della Repubblica             False
# lag7_Festa di San Giuseppe              False
# lag7_Giorno dei Morti                   False
# lag7_Giovedì Grasso                     False
# lag7_Immacolata Concezione              False
# lag7_Martedì Grasso                     False
# lag7_Ognissanti                         False
# lag7_Pasqua                             False
# lag7_Pentecoste                         False
# lag7_Primo dell'Anno                    False
# lag7_San Valentino                      False
# lag7_Santo Stefano                      False
# lag7_Ultimo dell'Anno                   False
# lag11_Anniversario della Liberazione    False
# lag11_Carnevale                         False
# lag11_Domenica delle Palme              False
# lag11_Epifania                          False
# lag11_Ferragosto                        False
# lag11_Festa dei Lavoratori              False
# lag11_Festa della Mamma                 False
# lag11_Festa della Repubblica            False
# lag11_Festa di San Giuseppe             False
# lag11_Giorno dei Morti                  False
# lag11_Giovedì Grasso                    False
# lag11_Immacolata Concezione             False
# lag11_Martedì Grasso                    False
# lag11_Ognissanti                        False
# lag11_Pasqua                            False
# lag11_Pentecoste                        False
# lag11_Primo dell'Anno                   False
# lag11_San Valentino                     False
# lag11_Santo Stefano                     False
# lag11_Ultimo dell'Anno                  False
# lag12_Anniversario della Liberazione    False
# lag12_Carnevale                         False
# lag12_Domenica delle Palme              False
# lag12_Epifania                          False
# lag12_Ferragosto                        False
# lag12_Festa dei Lavoratori              False
# lag12_Festa della Mamma                 False
# lag12_Festa della Repubblica            False
# lag12_Festa di San Giuseppe             False
# lag12_Giorno dei Morti                  False
# lag12_Giovedì Grasso                    False
# lag12_Immacolata Concezione             False
# lag12_Martedì Grasso                    False
# lag12_Ognissanti                        False
# lag12_Pasqua                            False
# lag12_Pentecoste                        False
# lag12_Primo dell'Anno                   False
# lag12_San Valentino                     False
# lag12_Santo Stefano                     False
# lag12_Ultimo dell'Anno                  False
# lag13_Anniversario della Liberazione    False
# lag13_Carnevale                         False
# lag13_Domenica delle Palme              False
# lag13_Epifania                          False
# lag13_Ferragosto                        False
# lag13_Festa dei Lavoratori              False
# lag13_Festa della Mamma                 False
# lag13_Festa della Repubblica            False
# lag13_Festa di San Giuseppe             False
# lag13_Giorno dei Morti                  False
# lag13_Giovedì Grasso                    False
# lag13_Immacolata Concezione             False
# lag13_Martedì Grasso                    False
# lag13_Ognissanti                        False
# lag13_Pasqua                            False
# lag13_Pentecoste                        False
# lag13_Primo dell'Anno                   False
# lag13_San Valentino                     False
# lag13_Santo Stefano                     False
# lag13_Ultimo dell'Anno                  False
# neve                                    False
# pioggia                                 False
# pioggia nebbia                          False
# pioggia neve                            False
# pioggia neve nebbia                     False
# pioggia temporale                       False
# pioggia temporale nebbia                False
# sole                                    False
# temporale                               False
# lag1_neve                               False
# lag1_pioggia                            False
# lag1_pioggia nebbia                     False
# lag1_pioggia neve                       False
# lag1_pioggia neve nebbia                False
# lag1_pioggia temporale                  False
# lag1_pioggia temporale nebbia           False
# lag1_sole                               False
# lag1_temporale                          False
# lag5_neve                               False
# lag5_pioggia                            False
# lag5_pioggia nebbia                     False
# lag5_pioggia neve                       False
# lag5_pioggia neve nebbia                False
# lag5_pioggia temporale                  False
# lag5_pioggia temporale nebbia           False
# lag5_sole                               False
# lag5_temporale                          False
# lag6_neve                               False
# lag6_pioggia                            False
# lag6_pioggia nebbia                     False
# lag6_pioggia neve                       False
# lag6_pioggia neve nebbia                False
# lag6_pioggia temporale                  False
# lag6_pioggia temporale nebbia           False
# lag6_sole                               False
# lag6_temporale                          False
# lag7_neve                               False
# lag7_pioggia                            False
# lag7_pioggia nebbia                     False
# lag7_pioggia neve                       False
# lag7_pioggia neve nebbia                False
# lag7_pioggia temporale                  False
# lag7_pioggia temporale nebbia           False
# lag7_sole                               False
# lag7_temporale                          False
# lag11_neve                              False
# lag11_pioggia                           False
# lag11_pioggia nebbia                    False
# lag11_pioggia neve                      False
# lag11_pioggia neve nebbia               False
# lag11_pioggia temporale                 False
# lag11_pioggia temporale nebbia          False
# lag11_sole                              False
# lag11_temporale                         False
# lag12_neve                              False
# lag12_pioggia                           False
# lag12_pioggia nebbia                    False
# lag12_pioggia neve                      False
# lag12_pioggia neve nebbia               False
# lag12_pioggia temporale                 False
# lag12_pioggia temporale nebbia          False
# lag12_sole                              False
# lag12_temporale                         False
# lag13_neve                              False
# lag13_pioggia                           False
# lag13_pioggia nebbia                    False
# lag13_pioggia neve                      False
# lag13_pioggia neve nebbia               False
# lag13_pioggia temporale                 False
# lag13_pioggia temporale nebbia          False
# lag13_sole                              False
# t_media                                 False
# t_min                                   False
# umidità_percentuale                     False
# juventus                                False
# sales_change                            False
# day_sin                                 False
# day_cos                                 False
# month_sin                               False
# month_cos                               False
# lag1_sales                              False
# lag1_juventus                           False
# lag5_sales                              False
# lag5_juventus                           False
# lag6_sales                              False
# lag6_juventus                           False
# lag7_sales                              False
# lag7_juventus                           False
# lag11_sales                             False
# lag11_juventus                          False
# lag12_sales                             False
# lag12_juventus                          False
# lag13_sales                             False
# lag13_juventus                          False
# Anniversario della Liberazione          False
# Carnevale                               False
# Domenica delle Palme                    False
# Epifania                                False
# Ferragosto                              False
# Festa dei Lavoratori                    False
# Festa della Mamma                       False
# Festa della Repubblica                  False
# Festa di San Giuseppe                   False
# Giorno dei Morti                        False
# Giovedì Grasso                          False
# Immacolata Concezione                   False
# Martedì Grasso                          False
# Ognissanti                              False
# Pasqua                                  False
# Pentecoste                              False
# Primo dell'Anno                         False
# San Valentino                           False
# Santo Stefano                           False
# Ultimo dell'Anno                        False
# lag1_Anniversario della Liberazione     False
# lag1_Carnevale                          False
# lag1_Domenica delle Palme               False
# lag1_Epifania                           False
# lag1_Ferragosto                         False
# lag1_Festa dei Lavoratori               False
# lag1_Festa della Mamma                  False
# lag1_Festa della Repubblica             False
# lag1_Festa di San Giuseppe              False
# lag1_Giorno dei Morti                   False
# lag1_Giovedì Grasso                     False
# lag1_Immacolata Concezione              False
# lag1_Martedì Grasso                     False
# lag1_Ognissanti                         False
# lag1_Pasqua                             False
# lag1_Pentecoste                         False
# lag1_Primo dell'Anno                    False
# lag1_San Valentino                      False
# lag1_Santo Stefano                      False
# lag1_Ultimo dell'Anno                   False
# lag5_Anniversario della Liberazione     False
# lag5_Carnevale                          False
# lag5_Domenica delle Palme               False
# lag5_Epifania                           False
# lag5_Ferragosto                         False
# lag5_Festa dei Lavoratori               False
# lag5_Festa della Mamma                  False
# lag5_Festa della Repubblica             False
# lag5_Festa di San Giuseppe              False
# lag5_Giorno dei Morti                   False
# lag5_Giovedì Grasso                     False
# lag5_Immacolata Concezione              False
# lag5_Martedì Grasso                     False
# lag5_Ognissanti                         False
# lag5_Pasqua                             False
# lag5_Pentecoste                         False
# lag5_Primo dell'Anno                    False
# lag5_San Valentino                      False
# lag5_Santo Stefano                      False
# lag5_Ultimo dell'Anno                   False
# lag6_Anniversario della Liberazione     False
# lag6_Carnevale                          False
# lag6_Domenica delle Palme               False
# lag6_Epifania                           False
# lag6_Ferragosto                         False
# lag6_Festa dei Lavoratori               False
# lag6_Festa della Mamma                  False
# lag6_Festa della Repubblica             False
# lag6_Festa di San Giuseppe              False
# lag6_Giorno dei Morti                   False
# lag6_Giovedì Grasso                     False
# lag6_Immacolata Concezione              False
# lag6_Martedì Grasso                     False
# lag6_Ognissanti                         False
# lag6_Pasqua                             False
# lag6_Pentecoste                         False
# lag6_Primo dell'Anno                    False
# lag6_San Valentino                      False
# lag6_Santo Stefano                      False
# lag6_Ultimo dell'Anno                   False
# lag7_Anniversario della Liberazione     False
# lag7_Carnevale                          False
# lag7_Domenica delle Palme               False
# lag7_Epifania                           False
# lag7_Ferragosto                         False
# lag7_Festa dei Lavoratori               False
# lag7_Festa della Mamma                  False
# lag7_Festa della Repubblica             False
# lag7_Festa di San Giuseppe              False
# lag7_Giorno dei Morti                   False
# lag7_Giovedì Grasso                     False
# lag7_Immacolata Concezione              False
# lag7_Martedì Grasso                     False
# lag7_Ognissanti                         False
# lag7_Pasqua                             False
# lag7_Pentecoste                         False
# lag7_Primo dell'Anno                    False
# lag7_San Valentino                      False
# lag7_Santo Stefano                      False
# lag7_Ultimo dell'Anno                   False
# lag11_Anniversario della Liberazione    False
# lag11_Carnevale                         False
# lag11_Domenica delle Palme              False
# lag11_Epifania                          False
# lag11_Ferragosto                        False
# lag11_Festa dei Lavoratori              False
# lag11_Festa della Mamma                 False
# lag11_Festa della Repubblica            False
# lag11_Festa di San Giuseppe             False
# lag11_Giorno dei Morti                  False
# lag11_Giovedì Grasso                    False
# lag11_Immacolata Concezione             False
# lag11_Martedì Grasso                    False
# lag11_Ognissanti                        False
# lag11_Pasqua                            False
# lag11_Pentecoste                        False
# lag11_Primo dell'Anno                   False
# lag11_San Valentino                     False
# lag11_Santo Stefano                     False
# lag11_Ultimo dell'Anno                  False
# lag12_Anniversario della Liberazione    False
# lag12_Carnevale                         False
# lag12_Domenica delle Palme              False
# lag12_Epifania                          False
# lag12_Ferragosto                        False
# lag12_Festa dei Lavoratori              False
# lag12_Festa della Mamma                 False
# lag12_Festa della Repubblica            False
# lag12_Festa di San Giuseppe             False
# lag12_Giorno dei Morti                  False
# lag12_Giovedì Grasso                    False
# lag12_Immacolata Concezione             False
# lag12_Martedì Grasso                    False
# lag12_Ognissanti                        False
# lag12_Pasqua                            False
# lag12_Pentecoste                        False
# lag12_Primo dell'Anno                   False
# lag12_San Valentino                     False
# lag12_Santo Stefano                     False
# lag12_Ultimo dell'Anno                  False
# lag13_Anniversario della Liberazione    False
# lag13_Carnevale                         False
# lag13_Domenica delle Palme              False
# lag13_Epifania                          False
# lag13_Ferragosto                        False
# lag13_Festa dei Lavoratori              False
# lag13_Festa della Mamma                 False
# lag13_Festa della Repubblica            False
# lag13_Festa di San Giuseppe             False
# lag13_Giorno dei Morti                  False
# lag13_Giovedì Grasso                    False
# lag13_Immacolata Concezione             False
# lag13_Martedì Grasso                    False
# lag13_Ognissanti                        False
# lag13_Pasqua                            False
# lag13_Pentecoste                        False
# lag13_Primo dell'Anno                   False
# lag13_San Valentino                     False
# lag13_Santo Stefano                     False
# lag13_Ultimo dell'Anno                  False
# neve                                    False
# pioggia                                 False
# pioggia nebbia                          False
# pioggia neve                            False
# pioggia neve nebbia                     False
# pioggia temporale                       False
# pioggia temporale nebbia                False
# sole                                    False
# temporale                               False
# lag1_neve                               False
# lag1_pioggia                            False
# lag1_pioggia nebbia                     False
# lag1_pioggia neve                       False
# lag1_pioggia neve nebbia                False
# lag1_pioggia temporale                  False
# lag1_pioggia temporale nebbia           False
# lag1_sole                               False
# lag1_temporale                          False
# lag5_neve                               False
# lag5_pioggia                            False
# lag5_pioggia nebbia                     False
# lag5_pioggia neve                       False
# lag5_pioggia neve nebbia                False
# lag5_pioggia temporale                  False
# lag5_pioggia temporale nebbia           False
# lag5_sole                               False
# lag5_temporale                          False
# lag6_neve                               False
# lag6_pioggia                            False
# lag6_pioggia nebbia                     False
# lag6_pioggia neve                       False
# lag6_pioggia neve nebbia                False
# lag6_pioggia temporale                  False
# lag6_pioggia temporale nebbia           False
# lag6_sole                               False
# lag6_temporale                          False
# lag7_neve                               False
# lag7_pioggia                            False
# lag7_pioggia nebbia                     False
# lag7_pioggia neve                       False
# lag7_pioggia neve nebbia                False
# lag7_pioggia temporale                  False
# lag7_pioggia temporale nebbia           False
# lag7_sole                               False
# lag7_temporale                          False
# lag11_neve                              False
# lag11_pioggia                           False
# lag11_pioggia nebbia                    False
# lag11_pioggia neve                      False
# lag11_pioggia neve nebbia               False
# lag11_pioggia temporale                 False
# lag11_pioggia temporale nebbia          False
# lag11_sole                              False
# lag11_temporale                         False
# lag12_neve                              False
# lag12_pioggia                           False
# lag12_pioggia nebbia                    False
# lag12_pioggia neve                      False
# lag12_pioggia neve nebbia               False
# lag12_pioggia temporale                 False
# lag12_pioggia temporale nebbia          False
# lag12_sole                              False
# lag12_temporale                         False
# lag13_neve                              False
# lag13_pioggia                           False
# lag13_pioggia nebbia                    False
# lag13_pioggia neve                      False
# lag13_pioggia neve nebbia               False
# lag13_pioggia temporale                 False
# lag13_pioggia temporale nebbia          False
# lag13_sole                              ...
# lag13_temporale                         False
# Length: 256, dtype: bool

# %% [markdown]
# # Basic Model - Linear Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, RandomizedSearchCV

# %%
TEST_SIZE = 0.15

# %%
X = dataset.drop(columns=['sales', 'sales_change'])
y = dataset.sales

split_idx = dataset.iloc[int(len(dataset)*(1-TEST_SIZE))].name

X_train, X_test = X.loc[:split_idx], X.loc[split_idx:]
y_train, y_test = y.loc[:split_idx], y.loc[split_idx:]

sample_weights = [np.exp(t/float(len(y_train))) for t in range(len(y_train))]

# %%
plt.scatter([t for t in range(len(y_train))], sample_weights)

# %%
model = Ridge()

# %%
hyperparameters = {'alpha': np.linspace(start=0., stop=50., num=50)}

random_search = RandomizedSearchCV(estimator=model,
                                   param_distributions=hyperparameters,
                                   n_iter=50,
                                   cv=TimeSeriesSplit(n_splits=10),
                                   n_jobs=-1)

# %%
random_search.fit(X_train, y_train, sample_weight=sample_weights)
# Out:
# RandomizedSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                    error_score='raise-deprecating',
#                    estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                                    max_iter=None, normalize=False,
#                                    random_state=None, solver='auto',
#                                    tol=0.001),
#                    iid='warn', n_iter=50, n_jobs=-1,
#                    param_distributions={'alpha': array([ 0.        ,  1.02040816,  2.04081633,  3.06122449,  4.08163265,
#         5.1...
#        25.51020408, 26.53061224, 27.55102041, 28.57142857, 29.59183673,
#        30.6122449 , 31.63265306, 32.65306122, 33.67346939, 34.69387755,
#        35.71428571, 36.73469388, 37.75510204, 38.7755102 , 39.79591837,
#        40.81632653, 41.83673469, 42.85714286, 43.87755102, 44.89795918,
#        45.91836735, 46.93877551, 47.95918367, 48.97959184, 50.        ])},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)

# %%
random_search.cv_results_['mean_test_score']
# Out:
# array([-2.80846912e+25,  2.82326644e-01,  3.05307273e-01,  3.14619731e-01,
#         3.20068000e-01,  3.23933767e-01,  3.26987371e-01,  3.29551501e-01,
#         3.31783993e-01,  3.33772097e-01,  3.35569094e-01,  3.37210276e-01,
#         3.38720593e-01,  3.40118610e-01,  3.41418712e-01,  3.42632395e-01,
#         3.43769074e-01,  3.44836608e-01,  3.45841660e-01,  3.46789946e-01,
#         3.47686424e-01,  3.48535427e-01,  3.49340772e-01,  3.50105840e-01,
#         3.50833645e-01,  3.51526885e-01,  3.52187985e-01,  3.52819134e-01,
#         3.53422314e-01,  3.53999328e-01,  3.54551817e-01,  3.55081282e-01,
#         3.55589096e-01,  3.56076522e-01,  3.56544721e-01,  3.56994765e-01,
#         3.57427644e-01,  3.57844274e-01,  3.58245505e-01,  3.58632126e-01,
#         3.59004873e-01,  3.59364430e-01,  3.59711436e-01,  3.60046489e-01,
#         3.60370146e-01,  3.60682931e-01,  3.60985336e-01,  3.61277822e-01,
#         3.61560822e-01,  3.61834746e-01])

# %%
random_search.best_params_
# Out:
# {'alpha': 50.0}

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(estimator=model, 
                X=X_train, 
                y=y_train, 
                cv=TimeSeriesSplit(n_splits=10),
                n_jobs=-1)
# Out:
# array([0.26503059, 0.42715208, 0.06263224, 0.16665721, 0.33549739,
#        0.33940691, 0.19668608, 0.35682717, 0.35907972, 0.45367734])

# %%
best_model = random_search.best_estimator_

# %%
pred = np.round(best_model.predict(X_test))

# %% [markdown]
# **Observed vs Predicted**

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x=y_test, y=pred)
plt.plot([min(y_test), max(y_test)], [min(pred), max(pred)], lw=1.5, color='red', ls='--')
plt.xlabel('Observed Sales')
plt.ylabel('Predicted Sales')
plt.title('Observed vs Predicted')
plt.show()

# %% [markdown]
# ### Metrics

# %% [markdown]
# **Coefficient of Determination**

# %%
from sklearn.metrics import r2_score

r2_score(y_true=y_test, y_pred=pred)
# Out:
# 0.5037637362637362

# %% [markdown]
# **Average Percentage Error**

# %%
((y_test - pred)/y_test).abs().mean()
# Out:
# 0.16033790471415804

# %% [markdown]
# ## Time-Series Observed vs Prediction

# %% [markdown]
# **All time-series**

# %%
fig, ax = plt.subplots(figsize=(24, 6))
sns.lineplot(x='date', y='sales', data=df.loc[:split_idx], color='blue', alpha=0.6, label='training', ax=ax)
sns.lineplot(x='date', y='sales', data=df.loc[split_idx:], color='red', alpha=0.8, label='obs_test', ax=ax)
sns.lineplot(x=df.loc[split_idx:, 'date'], y=pred, color='black', label='pred_test', ax=ax)
plt.show()

# %% [markdown]
# **Test time-series**

# %%
fig, ax = plt.subplots(figsize=(18, 6))
sns.lineplot(x='date', y='sales', data=df.loc[split_idx:], color='red', alpha=0.8, label='obs_test', ax=ax)
sns.lineplot(x=df.loc[split_idx:, 'date'], y=pred, color='black', label='pred_test', ax=ax)
plt.show()

# %% [markdown]
# ## Prediction Error

# %%
results = pd.DataFrame({'date': df.loc[split_idx:, 'date'], 'y_true': y_test.values, 'y_pred': pred})

# %%
results.head()
# Out:
#            date  y_true  y_pred
# 1294 2019-02-26      26    32.0
# 1295 2019-02-27      23    28.0
# 1296 2019-02-28      36    27.0
# 1297 2019-03-01      27    37.0
# 1298 2019-03-02      58    38.0

# %%
results['residuals'] = results.y_true - results.y_pred
results['abs_res'] = results.residuals.abs()
results['mae'] = results.abs_res / results.y_true

# %%
results.sort_values(by=['abs_res'], ascending=False, inplace=True)

# %%
results = pd.merge(left=results, right=df, on='date')

# %%
sns.distplot(results.residuals)
plt.show()

# %%
sns.boxplot(results.residuals)
plt.show()

# %%
sns.scatterplot(x='dayname', y='residuals', data=results)
plt.axhline(0, color='black', lw=2.5, ls='--')
plt.axhline(-10, color='black', lw=1.5, ls='--')
plt.axhline(10, color='black', lw=1.5, ls='--')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='sales', y='residuals', hue='dayname', data=results)
plt.axhline(0, color='red', lw=2, ls='--')
plt.show()

# %%
results.holidays.fillna('#', inplace=True)
sns.scatterplot(x='holidays', y='residuals', data=results)
plt.axhline(0, color='black', lw=2.5, ls='--')
plt.axhline(-10, color='black', lw=1.5, ls='--')
plt.axhline(10, color='black', lw=1.5, ls='--')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Worst Predictions

# %%
worst_pred = results.query('mae > 0.10')

# %%
worst_pred
# Out:
#           date  y_true  y_pred  ...    ma-3std    ma+3std  sales_change
# 0   2019-07-07      57    32.0  ...  10.472244  46.527756      0.325581
# 1   2019-03-02      58    38.0  ...  25.272078  50.727922      1.148148
# 2   2019-08-10      12    29.0  ...  21.187822  33.312178     -0.538462
# 3   2019-03-30      58    41.0  ...  25.050100  49.949900      0.757576
# 4   2019-04-14      55    38.0  ...  14.646279  62.353721      0.122449
# ..         ...     ...     ...  ...        ...        ...           ...
# 151 2019-07-23      26    29.0  ...  21.513167  40.486833     -0.133333
# 152 2019-08-16      23    26.0  ...  20.376894  28.623106      0.000000
# 155 2019-08-09      26    29.0  ...  18.500000  32.500000      0.181818
# 157 2019-08-04      29    32.0  ...  19.054477  41.945523      0.260870
# 158 2019-05-09      27    30.0  ...  18.903194  41.596806     -0.129032
#
# [143 rows x 19 columns]
